# %%
n=int(input("enter the N rows :- "))
for i in range(n):
  for j in range(0,n-i-1):
    print(end=" ")
  for j in range(i+1):
    print("*", end=" ")
  print()
# Out:
# enter the N rows :- 10
#          *
#         * *
#        * * *
#       * * * *
#      * * * * *
#     * * * * * *
#    * * * * * * *
#   * * * * * * * *
#  * * * * * * * * *
# * * * * * * * * * *

# %%
k=int(input("enter the N rows :- "))
for r in range(k+1):
  print("*"*r)
# Out:
# enter the N rows :- 7
#
# *
# **
# ***
# ****
# *****
# ******
# *******

# %%
r=int(input("enter the N rows :- "))
for i in range(r,0,-1):
  for j in range(0,r-i):
    print(end=" ")
  for j in range(i):
    print("*", end=" ")
  print()
# Out:
# enter the N rows :- 10
# * * * * * * * * * *
#  * * * * * * * * *
#   * * * * * * * *
#    * * * * * * *
#     * * * * * *
#      * * * * *
#       * * * *
#        * * *
#         * *
#          *

# %%
n=int(input("enter the N rows :- "))
for i in range(n):
  for j in range(0,n-i-1):
    print(end=" ")
  for j in range(i+1):
    print("*", end=" ")
  print()
for i in range(n-1,0,-1):
  for j in range(0,n-i):
    print(end=" ")
  for j in range(i):
    print("*", end=" ")
  print()
# Out:
# enter the N rows :- 20
#                    *
#                   * *
#                  * * *
#                 * * * *
#                * * * * *
#               * * * * * *
#              * * * * * * *
#             * * * * * * * *
#            * * * * * * * * *
#           * * * * * * * * * *
#          * * * * * * * * * * *
#         * * * * * * * * * * * *
#        * * * * * * * * * * * * *
#       * * * * * * * * * * * * * *
#      * * * * * * * * * * * * * * *
#     * * * * * * * * * * * * * * * *
#    * * * * * * * * * * * * * * * * *
#   * * * * * * * * * * * * * * * * * *
#  * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * *
#  * * * * * * * * * * * * * * * * * * *
#   * * * * * * * * * * * * * * * * * *
#    * * * * * * * * * * * * * * * * *
#     * * * * * * * * * * * * * * * *
#      * * * * * * * * * * * * * * *
#       * * * * * * * * * * * * * *
#        * * * * * * * * * * * * *
#         * * * * * * * * * * * *
#          * * * * * * * * * * *
#           * * * * * * * * * *
#            * * * * * * * * *
#             * * * * * * * *
#              * * * * * * *
#               * * * * * *
#                * * * * *
#                 * * * *
#                  * * *
#                   * *
#                    *
