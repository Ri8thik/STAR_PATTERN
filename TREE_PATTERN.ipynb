# %%
n=int(input("enter the N rows :- "))
for i in range(n):
  for j in range(0,n-i-1):
    print(end=" ")
  for j in range(i+1):
    print("*", end=" ")
  print()
# Out:
# enter the N rows :- 10
#          *
#         * *
#        * * *
#       * * * *
#      * * * * *
#     * * * * * *
#    * * * * * * *
#   * * * * * * * *
#  * * * * * * * * *
# * * * * * * * * * *
