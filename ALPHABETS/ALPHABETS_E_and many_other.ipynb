# %% [markdown]
# FOR E

# %%
for r in range(7):
    for c in range(5):
        if (c==0) or (r==0 or r==6) or (c<4 and r==3):
            print("*", end="")
        else:
            print(end=" ")
    print()
print()
# Out:
# *****
# *
# *
# ****
# *
# *
# *****

# %% [markdown]
# FOR F

# %%
for r in range(7):
    for c in range(5):
        if (c==0) or (r==0 or r==3):
            print("*", end="")
        else:
            print(end=" ")
    print()
print()
# Out:
# *****
# *
# *
# *****
# *
# *
# *

# %% [markdown]
# FOR G

# %%
for r in range(7):
    for c in range(6):
        if (c==0) or ((r==0 or r==6) and (c!=5)) or ((c==4) and (r==3 or r==4 or r==5)) or ((r==3) and (c==3 or c==5)) :
            print("*", end="")
        else:
            print(end=" ")
    print()
# Out:
# *****
# *
# *
# *  ***
# *   *
# *   *
# *****

# %% [markdown]
# FOR H

# %%
for r in range(7):
  for c in range(5):
    if (c==0 or c==4) or (r==3):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# *   *
# *   *
# *   *
# *****
# *   *
# *   *
# *   *

# %% [markdown]
# FOR I

# %%
for r in range(7):
  for c in range(5):
    if (c==2) or (r==0 or r==6):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# *****
#   *
#   *
#   *
#   *
#   *
# *****

# %% [markdown]
# FOR J

# %%
for r in range(7):
  for c in range(5):
    if (c==2) or (r==0) or (r==6 and (c==0 or c==1 or c==2)):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# *****
#   *
#   *
#   *
#   *
#   *
# ***

# %% [markdown]
# ANOTHER J

# %%
for r in range(7):
  for c in range(5):
    if (c==2) or (r==0) or (r==6 and c==2) or (r==5 and c==1) or (r==4 and c==0):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# *****
#   *
#   *
#   *
# * *
#  **
#   *

# %% [markdown]
# FOR K

# %%
for r in range(7):
  for c in range(5):
    if (c==0) or (c==1 and r==3) or (c==2 and (r==2 or r==4)) or (c==3 and (r==1 or r==5)) or (c==4 and (r==0 or r==6)):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# *   *
# *  *
# * *
# **
# * *
# *  *
# *   *

# %% [markdown]
# FOR L

# %%
for r in range(7):
  for c in range(5):
    if (c==0) or (r==6):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# *
# *
# *
# *
# *
# *
# *****

# %% [markdown]
# FOR M

# %%
for r in range(7):
  for c in range(7):
    if (c==0) or (c==6) or (c==1 and r==1) or (c==2 and r==2) or (c==3 and r==3) or (c==4 and r==2) or (c==5 and r==1):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# *     *
# **   **
# * * * *
# *  *  *
# *     *
# *     *
# *     *

# %% [markdown]
# FOR N

# %%
for r in range(6):
  for c in range(6):
    if (c==0) or (c==5) or (c==1 and r==1) or (c==2 and r==2) or (c==3 and r==3) or (c==4 and r==4):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# *    *
# **   *
# * *  *
# *  * *
# *   **
# *    *

# %% [markdown]
# FOR O

# %%
for r in range(7):
  for c in range(5):
    if ((c==0 or c==4 ) and (r!=0 and r!=6)) or ((r==0 or r==6) and (c>0 and c<4)):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
#  ***
# *   *
# *   *
# *   *
# *   *
# *   *
#  ***

# %% [markdown]
# FOR P

# %%
for r in range(7):
  for c in range(5):
    if (c==0) or ((r==0 or r==3) and (c!=4)) or ((r==1 or r==2) and c==4):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# ****
# *   *
# *   *
# ****
# *
# *
# *

# %% [markdown]
# FOR Q

# %%
for r in range(8):
  for c in range(5):
    if ((c==0 or c==4) and (r>0 and r<6)) or ((r==0) and (c>0 and c<4)) or ((r==6) and (c>0 and c<4)) or (r==5 and c==1) or (r==7 and c==3):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
#  ***
# *   *
# *   *
# *   *
# *   *
# **  *
#  ***
#    *

# %% [markdown]
# FOR R

# %%
for r in range(7):
  for c in range(5):
    if (c==0) or ((r==0 or r==3) and (c>0 and c<4)) or ((c==4) and (r!=0 and r!=3)):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# ****
# *   *
# *   *
# ****
# *   *
# *   *
# *   *

# %% [markdown]
# FOR S

# %%
for r in range(7):
  for c in range(5):
    if ((c>0 and c<4)and (r==0 or r==3 or r==6)) or ((c==0) and (r==1 or r==2)) or ((c==4) and (r==4 or r==5)):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
#  ***
# *
# *
#  ***
#     *
#     *
#  ***

# %% [markdown]
# FOR T

# %%
for r in range(7):
  for c in range(5):
    if (c==2) or (r==0):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# *****
#   *
#   *
#   *
#   *
#   *
#   *

# %% [markdown]
# FOR U

# %%
for r in range(7):
  for c in range(5):
    if (c==0 and r!=6) or (c==4 and r!=6) or ((r==6) and (c>0 and c<4)):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# *   *
# *   *
# *   *
# *   *
# *   *
# *   *
#  ***

# %% [markdown]
# FOR V

# %%
for r in range(4):
  for c in range(7):
    if (c==0 and r==0) or (c==1 and r==1) or (c==2 and r==2) or (c==3 and r==3) or (c==4 and r==2) or (c==5 and r==1) or (c==6 and r==0):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# *     *
#  *   *
#   * *
#    *

# %% [markdown]
# FOR W

# %%
for r in range(4):
  for c in range(7):
    if (c==0) or (c==6) or (c==1 and r==2)or (c==2 and r==1) or (c==3 and r==0) or (c==4 and r==1) or (c==5 and r==2):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# *  *  *
# * * * *
# **   **
# *     *

# %% [markdown]
# FOR X

# %%
for r in range(5):
  for c in range(5):
    if ((c==0 or c==4) and (r==0 or r==4)) or ((c==1 or c==3) and (r==1 or r==3)) or (c==2 and r==2):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# *   *
#  * *
#   *
#  * *
# *   *

# %% [markdown]
# FOR Y

# %%
for r in range(5):
  for c in range(5):
    if ((c==0 or c==4) and (r==0)) or ((c==1 or c==3) and (r==1)) or ((c==2) and (r>1)):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# *   *
#  * *
#   *
#   *
#   *

# %% [markdown]
# FOR Z

# %%
for r in range(6):
  for c in range(6):
    if (r==0) or (r==5) or (c==1 and r==4) or (c==2 and r==3) or (c==3 and r==2) or (c==4 and r==1):
      print("*", end="")
    else:
      print(end=" ")
  print()
# Out:
# ******
#     *
#    *
#   *
#  *
# ******
